# %%
pip install flask
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install flask_cors
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os 
print(os.getcwd())
# Out:
# C:\Users\frontech

# %%
os.chdir(r'C:\Users\frontech/review-scrapper-aws-main')

# %%
import os 
print(os.getcwd())
# Out:
# C:\Users\frontech\review-scrapper-aws-main

# %%
# agar hum koi jis install karna to mam jupyter note book and couda promd ka use kar sate hai lekin 
# hum ak ak karke kitana install karna jupyter lab me , conda promt,termnal me 
# use jghah  hum ak se aadik jis install karna to hum kya karte hai ki ak .txt fill bana lete hai use jo hume install karna o likh dete hai 
# process hai terminal me sao = .txt agar kese folder me ho to ye karo termnail cd folder name iska matlab folder ke ander jane ko kaha rehe ho than 
# use ke bad termanil me pip install -r .txt name de do

# %%
#agar tumr python fill(.py) ko run karna hai to terminal me karna hai = .py agar kese folder me ho to ye karo termnail cd folder name iska matlab folder ke ander jane ko kaha rehe ho 
#than python .py kar do
#link nahi dekeh .py  call karege to tum google par  jana hoga ager tumara host="0.0.0.0" ho to hi google me http://127.0.0.1:5000/ search karo gbe than tumar khol jayega

# %%
from flask import Flask, render_template, request,jsonify
from flask_cors import CORS,cross_origin
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq
import logging 
import pymongo

logging.basicConfig(filename="scrapper.log" , level=logging.INFO)

app = Flask(__name__)


@app.route("/", methods = ['GET'])
def homepage():
    return render_template("index.html")

@app.route("/review" , methods = ['POST' , 'GET'])
def index():
    if request.method == 'POST':
        try:
            searchString = request.form['content'].replace(" ","")
            flipkart_url = "https://www.flipkart.com/search?q=" + searchString
            uClient = uReq(flipkart_url)
            flipkartPage = uClient.read()
            uClient.close()
            flipkart_html = bs(flipkartPage, "html.parser")
            bigboxes = flipkart_html.find_all("div", {"class":"cPHDOP col-12-12"})
            del bigboxes[0:2]
            box = bigboxes[0]
            productLink = "https://www.flipkart.com" + box.find("a", {"class":"CGtC98"})['href'] 
            prodRes = requests.get(productLink)
            prodRes.encoding='utf-8'
            prod_html = bs(prodRes.text, "html.parser")
           
            commentboxes = prod_html.find_all("div",{"class" :"col EPCmJX"})

            filename = searchString + ".csv"
            fw = open(filename, "w")
            headers = "Product, Customer Name, Rating, Heading, Comment \n"
            fw.write(headers)
            reviews = []
            for commentbox in commentboxes:
                try:
                    #name.encode(encoding='utf-8')
                    name = commentbox.find("p",{"class":'_2NsDsF AwS1CA'}).text

                except:
                    logging.info("name")

                try:
                    #rating.encode(encoding='utf-8')
                    rating = commentbox.find("div", {"class":"XQDdHH Ga3i8K"}).text


                except:
                    rating = 'No Rating'
                    logging.info("rating")

                try:
                    #commentHead.encode(encoding='utf-8')
                    commentHead = commentbox.find("p", {"class" : "z9E0IG"}).text

                except:
                    commentHead = 'No Comment Heading'
                    logging.info(commentHead)
                try:
                    custComment = commentbox.find('div', {'class': ''}).text
                    
                except Exception as e:
                    custComment = "No Comment"
                    logging.info(e)


                mydict = {"Product": searchString, "Name": name, "Rating": rating, "CommentHead": commentHead,
                          "Comment": custComment}
                reviews.append(mydict)
            logging.info("log my final result {}".format(reviews))
            #For example:@ → %40 # → %23! → %21
            client = pymongo.MongoClient("mongodb+srv://sajan:Sajan%40123@cluster0.5u8yykc.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
    
            db = client['review_scrap']
            review_col = db['review_scrap_data']
            review_col.insert_many(reviews)
            return render_template('result.html', reviews=reviews)
        except Exception as e:
            logging.info(e)
            return 'something is wrong'
    # return render_template('results.html')

    else:
    
        return render_template('index.html')


if __name__ == "__main__":
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off

# %%
from flask import Flask, render_template, request, jsonify
app = Flask(__name__)

@app.route('/', methods=['GET', 'POST'])
def home_page():
    return render_template('index.htm')

@app.route('/math', methods=['POST'])
def math_operation():
    if request.method == 'POST':  
        ops = request.form['operation']
        num1 = int(request.form['num1'])
        num2 = int(request.form['num2'])

        if ops == 'add':
            r = num1 + num2
            result = f"The sum of {num1} and {num2} is {r}"

        elif ops == 'subtract':
            r = num1 - num2
            result = f"The subtraction of {num1} and {num2} is {r}"

        elif ops == 'multiply':
            r = num1 * num2
            result = f"The multiplication of {num1} and {num2} is {r}"
    
        elif ops == 'divide':
            try:
               
                r = num1 / num2
                result = f"The division of {num1} by {num2} is {r}" 
            except: 
                result = "Division by zero is not possible."

        return render_template('results.htm', result=result)

if __name__ == "__main__":
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://10.194.250.103:5000
# Press CTRL+C to quit
# [2025-10-18 12:33:51,112] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\frontech\.conda\envs\mynewenv\Lib\site-packages\flask\app.py", line 1511, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\frontech\.conda\envs\mynewenv\Lib\site-packages\flask\app.py", line 919, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\frontech\.conda\envs\mynewenv\Lib\site-packages\flask\app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
# ...

# %%
import requests 
from bs4 import BeautifulSoup as bs 
from   urllib.request import urlopen as uReq
import logging

# %%
flipkart_url = "https://www.flipkart.com/search?q=" + "iphone11"

# %%
uClient = uReq(flipkart_url)
flipkartPage = uClient.read()
uClient.close()
flipkart_html = bs(flipkartPage, "html.parser")

# %%
 bigboxes = flipkart_html.find_all("div", {"class":"cPHDOP col-12-12"})

# %%
del bigboxes[0:2]

# %%
         

productLink = "https://www.flipkart.com" +bigboxes[0].find("a", {"class":"CGtC98"})['href']

# %%
productLink
# Out:
# 'https://www.flipkart.com/apple-iphone-11-black-64-gb/p/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYHWAXCG&marketplace=FLIPKART&q=iphone11&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=4f3232ea-da32-4808-82c6-c088bdfa9ab2.MOBFWQ6BXGJCEYNY.SEARCH&ppt=None&ppn=None&ssid=54g7r0bdsg0000001760770929130&qH=d6db477051465f9a'

# %%
            prodRes = requests.get(productLink)
            prodRes.encoding='utf-8'
            prod_html = bs(prodRes.text, "html.parser")
            print(prod_html)
# Out:
# <!DOCTYPE html>
# ...

# %%
  commentboxes = prod_html.find_all("div",{"class" :"col EPCmJX"})

# %%
commentboxes[0].find('div', {'class': ''}).text
# Out:
# 'Really satisfied with the Product I received... It’s totally genuine and the packaging was also really good so if ur planning to buy just go for it.'

# %%
commentboxes[0].find("p", {"class" : "z9E0IG"}).text
# Out:
# 'Simply awesome'

# %%
commentboxes[0].find("div", {"class":"XQDdHH Ga3i8K"}).text
# Out:
# '5'

# %%
  commentboxes[0].find('div', {'class':"Be4x5X d517go"})
# Out:
# <div class="Be4x5X d517go" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202011/blobio-imr-202011_e4b34b9e355e4836ade8b1f6345ee73b.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div>

# %%
img_tag = commentboxes[5].find('div', {'class':"Be4x5X d517go"}).find('img')
if img_tag:
    img_url = img_tag['src']
    print(img_url)
else:
    print("Image not found")
# Out:
# Image not found
