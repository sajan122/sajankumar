# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.linspace(0,10,200) # 0 se 10  number tak ke beach  200 data genrate karke de raha hai

# %%
x
# Out:
# array([ 0.        ,  0.05025126,  0.10050251,  0.15075377,  0.20100503,
#         0.25125628,  0.30150754,  0.35175879,  0.40201005,  0.45226131,
#         0.50251256,  0.55276382,  0.60301508,  0.65326633,  0.70351759,
#         0.75376884,  0.8040201 ,  0.85427136,  0.90452261,  0.95477387,
#         1.00502513,  1.05527638,  1.10552764,  1.15577889,  1.20603015,
#         1.25628141,  1.30653266,  1.35678392,  1.40703518,  1.45728643,
#         1.50753769,  1.55778894,  1.6080402 ,  1.65829146,  1.70854271,
#         1.75879397,  1.80904523,  1.85929648,  1.90954774,  1.95979899,
#         2.01005025,  2.06030151,  2.11055276,  2.16080402,  2.21105528,
#         2.26130653,  2.31155779,  2.36180905,  2.4120603 ,  2.46231156,
#         2.51256281,  2.56281407,  2.61306533,  2.66331658,  2.71356784,
#         2.7638191 ,  2.81407035,  2.86432161,  2.91457286,  2.96482412,
#         3.01507538,  3.06532663,  3.11557789,  3.16582915,  3.2160804 ,
# ...

# %%
x.ndim
# Out:
# 1

# %%
y = np.sin(x)

# %%
y
# Out:
# array([ 0.        ,  0.05023011,  0.10033341,  0.15018339,  0.19965422,
#         0.24862099,  0.29696008,  0.34454944,  0.39126893,  0.43700061,
#         0.481629  ,  0.52504145,  0.56712835,  0.60778345,  0.6469041 ,
#         0.68439153,  0.72015112,  0.75409257,  0.78613019,  0.8161831 ,
#         0.84417544,  0.87003651,  0.89370105,  0.91510929,  0.9342072 ,
#         0.95094655,  0.96528509,  0.97718662,  0.98662108,  0.99356467,
#         0.99799984,  0.99991541,  0.99930653,  0.99617474,  0.99052796,
#         0.98238043,  0.97175273,  0.95867168,  0.94317032,  0.92528777,
#         0.90506919,  0.88256563,  0.85783388,  0.8309364 ,  0.80194109,
#         0.77092115,  0.7379549 ,  0.70312557,  0.66652108,  0.62823386,
#         0.58836056,  0.54700186,  0.50426216,  0.46024937,  0.41507461,
#         0.36885193,  0.32169803,  0.27373195,  0.22507478,  0.17584939,
#         0.12618003,  0.07619211,  0.02601183, -0.02423412, -0.07441889,
# ...

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.xlabel('this is x data')
plt.ylabel('this is y data')
plt.title('this is my title')
plt.show()

# %%
x = np.random.rand(50)# random data ko produt(bana) karta hai
y = np.random.rand(50)
plt.scatter(x,y)

# %%
x
# Out:
# array([0.18701997, 0.47123479, 0.157894  , 0.07546948, 0.62182936,
#        0.50892417, 0.94429042, 0.23711998, 0.7503092 , 0.8118926 ,
#        0.7539002 , 0.4770597 , 0.97644986, 0.4822622 , 0.74463675,
#        0.51128457, 0.39477076, 0.93146651, 0.19789553, 0.89545422,
#        0.7628796 , 0.66457131, 0.64931965, 0.98562442, 0.3703005 ,
#        0.67154912, 0.8851808 , 0.99192169, 0.04157301, 0.8708535 ,
#        0.20275674, 0.46954165, 0.68025226, 0.72870615, 0.14414085,
#        0.60202285, 0.65100598, 0.44318416, 0.70662733, 0.33079238,
#        0.68476971, 0.9764969 , 0.55342144, 0.41016095, 0.17816098,
#        0.7198323 , 0.24814711, 0.64751275, 0.52098951, 0.94964338])

# %%
y
# Out:
# array([0.98330908, 0.89426951, 0.18486964, 0.06972075, 0.55534925,
#        0.31293863, 0.98409879, 0.58459137, 0.06849046, 0.32195823,
#        0.66834943, 0.85680159, 0.77022256, 0.33431496, 0.97729636,
#        0.17572191, 0.50545718, 0.19301884, 0.19689903, 0.30527828,
#        0.35529078, 0.311817  , 0.46557563, 0.27717077, 0.94864177,
#        0.72408541, 0.18058253, 0.18267312, 0.54150549, 0.88594395,
#        0.53512983, 0.0373908 , 0.0155257 , 0.82964084, 0.47531592,
#        0.88894962, 0.4789526 , 0.67831417, 0.3126751 , 0.96147938,
#        0.17269454, 0.86835343, 0.93445335, 0.41142859, 0.41917958,
#        0.11974311, 0.44425306, 0.58791476, 0.78591665, 0.40177206])

# %%
colours = np.random.rand(50) # jitana data ganreat kar reho ho utand(50) dena hoga x = np.random.rand(50) sane data(50)
size = np.random.rand(50)*100  #jitana data ganreat kar reho ho utand(50) dena hoga x = np.random.rand(50) sane data(50)
plt.scatter(x,y, c=colours, s=size, alpha=0.8) #alpha colors intcete (clour ke ghaharae ko bata hai )
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title("DATA")
# Out:
# Text(0.5, 1.0, 'DATA')

# %%
plt.scatter(x,y, c=x, s=y*300, alpha=0.7) #beeter trika hai you can s = x and c = y le sakte ho
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title("DATA")
# Out:
# Text(0.5, 1.0, 'DATA')

# %%
x  = ['a','b','c','d','e']

# %%
y = np.random.rand(5)

# %%
y
# Out:
# array([0.02437355, 0.60977402, 0.61402692, 0.59475039, 0.36208591])

# %%
plt.bar(y,x) # by defaulit phela likha huaa x axis samjata hai and second y axis samjhta hai wala par data dal deta hai axis dekhakar
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(x,y)
plt.xlabel('x axis')
plt.ylabel(' y axis')

plt.title('BAR PLOT')
# Out:
# Text(0.5, 1.0, 'BAR PLOT')

# %%
plt.barh(x,y) #barh kya hua ulta ho gaya x axis ka valu y axis chal gaya y axis tha x axis me aagaya
plt.xlabel('x axis')
plt.ylabel(' y axis')

plt.title('BAR PLOT')
# Out:
# Text(0.5, 1.0, 'BAR PLOT')

# %%
x
# Out:
# array([ 0.        ,  0.05025126,  0.10050251,  0.15075377,  0.20100503,
#         0.25125628,  0.30150754,  0.35175879,  0.40201005,  0.45226131,
#         0.50251256,  0.55276382,  0.60301508,  0.65326633,  0.70351759,
#         0.75376884,  0.8040201 ,  0.85427136,  0.90452261,  0.95477387,
#         1.00502513,  1.05527638,  1.10552764,  1.15577889,  1.20603015,
#         1.25628141,  1.30653266,  1.35678392,  1.40703518,  1.45728643,
#         1.50753769,  1.55778894,  1.6080402 ,  1.65829146,  1.70854271,
#         1.75879397,  1.80904523,  1.85929648,  1.90954774,  1.95979899,
#         2.01005025,  2.06030151,  2.11055276,  2.16080402,  2.21105528,
#         2.26130653,  2.31155779,  2.36180905,  2.4120603 ,  2.46231156,
#         2.51256281,  2.56281407,  2.61306533,  2.66331658,  2.71356784,
#         2.7638191 ,  2.81407035,  2.86432161,  2.91457286,  2.96482412,
#         3.01507538,  3.06532663,  3.11557789,  3.16582915,  3.2160804 ,
# ...

# %%
y
# Out:
# array([ 0.        ,  0.05023011,  0.10033341,  0.15018339,  0.19965422,
#         0.24862099,  0.29696008,  0.34454944,  0.39126893,  0.43700061,
#         0.481629  ,  0.52504145,  0.56712835,  0.60778345,  0.6469041 ,
#         0.68439153,  0.72015112,  0.75409257,  0.78613019,  0.8161831 ,
#         0.84417544,  0.87003651,  0.89370105,  0.91510929,  0.9342072 ,
#         0.95094655,  0.96528509,  0.97718662,  0.98662108,  0.99356467,
#         0.99799984,  0.99991541,  0.99930653,  0.99617474,  0.99052796,
#         0.98238043,  0.97175273,  0.95867168,  0.94317032,  0.92528777,
#         0.90506919,  0.88256563,  0.85783388,  0.8309364 ,  0.80194109,
#         0.77092115,  0.7379549 ,  0.70312557,  0.66652108,  0.62823386,
#         0.58836056,  0.54700186,  0.50426216,  0.46024937,  0.41507461,
#         0.36885193,  0.32169803,  0.27373195,  0.22507478,  0.17584939,
#         0.12618003,  0.07619211,  0.02601183, -0.02423412, -0.07441889,
# ...

# %%
plt.plot(x,y)
plt.xlabel('this is x data')
plt.ylabel('this is y data')
plt.title('this is my title')
plt.show()

# %%
plt.plot(x,y,'--b')
plt.xlabel('this is x data')
plt.ylabel('this is y data')
plt.title('this is my title')
plt.show()

# %%
plt.figure(figsize=(8,2)) # i thik 8 lenght and 2 hight first nuber lenght and scond nuber hight hai 
plt.plot(x,y,'--r')
plt.xlabel('this is x data')
plt.ylabel('this is y data')
plt.title('this is my title') 

plt.show()

# %%
plt.figure(figsize=(8,2)) # i thik 8 lenght and 2 hight first nuber lenght and scond nuber hight hai 
plt.plot(x,y,'--r')
plt.xlabel('this is x data')
plt.ylabel('this is y data')
plt.title('this is my title') 
plt.grid()
plt.show()

# %%
x = np.random.rand(50)# random data ko produt(bana) karta hai
y = np.random.rand(50)
colours = np.random.rand(50) # jitana data ganreat kar reho ho utand(50) dena hoga x = np.random.rand(50) sane data(50)
size = np.random.rand(50)*1000  #jitana data ganreat kar reho ho utand(50) dena hoga x = np.random.rand(50) sane data(50)
plt.scatter(x,y, c=colours, s=size, alpha=0.8) #alpha colors intcete (clour ke ghaharae ko bata hai )
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title("DATA")
# Out:
# Text(0.5, 1.0, 'DATA')

# %%
x = np.random.rand(50)
y = np.random.rand(50)
colours = np.random.rand(50) 
size = np.random.rand(50)*1000  
plt.scatter(x,y, c='r', s=size, alpha=0.5) # you can your clour name 
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title("DATA")
# Out:
# Text(0.5, 1.0, 'DATA')

# %%
x = np.random.rand(50)
y = np.random.rand(50)
colours = np.random.rand(50) 
size = np.random.rand(50)*1000  
plt.scatter(x,y, c='#A64D13', s=size, alpha=0.5) # you can put clour code A64D13 google sarch clour code put first #
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title("DATA")
# Out:
# Text(0.5, 1.0, 'DATA')

# %%
x = np.random.rand(50)
y = np.random.rand(50)
colours = np.random.rand(50) 
size = np.random.rand(50)*1000  
plt.scatter(x,y, c='#A64D13', s=size, alpha=0.5,marker='v') # marker repregent karne ka trika tum dot se ya v ya x etc kese kaena chayate 
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title("DATA")
# Out:
# Text(0.5, 1.0, 'DATA')

# %%
x = np.random.rand(3,4) # is trake dat h
y = np.random.rand(3,4)
colours = np.random.rand(3,4) 
size = np.random.rand(3,4)*1000  
plt.scatter(x,y, c='#A64D13', s=size, alpha=0.5,marker='v') # marker repregent karne ka trika tum dot se ya v ya x etc kese kaena chayate 
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title("DATA")
# Out:
# Text(0.5, 1.0, 'DATA')

# %%
x = [4,5,6,7,8,9]
y = [6,7,8,9,10,11]
plt.plot(x,y)
plt.show()

# %%
x = [4,5,6,7,8,9]
y = [60,7,80,9,40,11]
plt.plot(x,y)
plt.show()

# %%
x = [4,5,6,7,8,9]
y = [60,7,80,9,40,11]
plt.scatter(x,y)
plt.show()

# %%
data = [1,2,3,4,4,5,1,2,3,4,5,6,1,2,3]

# %%
plt.hist(data , color="b") # data le raha x axis me than y axis  autmaticlly frg(kitna bar repeat hua hai ) o data(nunber)  le raha hai
# Out:
# (array([3., 0., 3., 0., 3., 0., 3., 0., 2., 1.]),
#  array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data) 
plt.show()

# %%
x = [4,5,6,7,8,9]
y = [60,7,80,9,40,11]

plt.scatter(x,y,c=y) # automatically 
plt.show()

# %%
x = [4,5,6,7,8,9]
y = [60,7,80,9,40,11]
colours = ['red','blue','#4E301D','yellow','green','#A64D13']
plt.scatter(x,y,c=colours) # manually
plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50) 
z = np.random.rand(50)
fig = plt.figure()
ax = fig.add_subplot(projection='3d') # like lenght 
ax.scatter(x,y,x)
plt.show()

# %%
x = np.random.rand(3,4)
y = np.random.rand(3,4) 
z = np.random.rand(3,4)
fig = plt.figure()
ax = fig.add_subplot(projection='3d') # like lenght 
ax.scatter(x,y,x)
plt.show()

# %%
import pandas as pd

# %%
df = pd.DataFrame([{'data1':20,
              'data2': 30,
              'data3': 50}])

# %%
df
# Out:
#    data1  data2  data3
# 0     20     30     50

# %%
l = df.loc[0]

# %%
l
# Out:
# data1    20
# data2    30
# data3    50
# Name: 0, dtype: int64

# %%
type(l) # hanesa serise se hi graph genret kar sate chaye koi bhi graph ho dataform se nahi kar sate ho
# Out:
# pandas.core.series.Series

# %%
plt.figure(figsize=(7,8))
name =  ['data1','data2','data3']
plt.pie(l, colors= ['yellow','blue','#A64D13'],labels=name,autopct='%0.1f%%')

plt.show()

# %%
df1 = pd.DataFrame({'data1':[20,30,40],
              'data2': [30,50,60],
              'data3': [50,60,70]})

# %%
df1
# Out:
#    data1  data2  data3
# 0     20     30     50
# 1     30     50     60
# 2     40     60     70

# %%
df[0] # you dont this like opersatio frome datafriom
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\.conda\envs\mynewenv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 df[0]
#
# ...

# %%
x = df1[['data1','data2','data3']].stack() # ak se adhik collums ko ak sath serise badlana chahate ho to  .stack call karo

# %%
x
# Out:
# 0  data1    20
#    data2    30
#    data3    50
# 1  data1    30
#    data2    50
#    data3    60
# 2  data1    40
#    data2    60
#    data3    70
# dtype: int64
